# %% [markdown]
# This verifies that calc_rank and calc_rank_analytic are the same now!

# %%
from Ranking_exp import Ranking_exp
from TI import TI
import numpy as np
import matplotlib.pyplot as plt

n = 7
k_o = 0.4
k_s = 1
k_d = 0
alpha = 1 - (2 * (k_o/k_s))
alpha_prime = k_o/k_s
p = 6
q = 2
c_var = 0
lamb_val = np.arccosh((1+c_var)/(1-alpha))

sim = Ranking_exp(n, k_o, k_s, k_d, p, q, c_var)
ranks = sim.calc_rank()  # Get rankings for current n

plt.title(f'Ranking exception')
plt.xlabel('Object')
plt.ylabel('Rankings')
plt.grid(True)
x_vals = np.arange(1, n+1)  # X-axis ticks every 1
plt.plot(x_vals, ranks)

# Show the plot
plt.show()

# %%
#Double Check Formula

from Ranking_exp import Ranking_exp
from TI import TI
import numpy as np
import matplotlib.pyplot as plt

n = 7
k_o = 0.4
k_s = 1
k_d = 0
alpha = 1 - (2 * (k_o/k_s))
alpha_prime = k_o/k_s
p = 6
q = 2
c_var = 0
lamb_val = np.arccosh((1+c_var)/(1-alpha))

sim = Ranking_exp(n, k_o, k_s, k_d, p, q, c_var)
ranks = sim.calc_rank_analytic()  # Get rankings for current n

plt.title(f'Ranking exception')
plt.xlabel('Object')
plt.ylabel('Rankings')
plt.grid(True)
x_vals = np.arange(1, n+1)  # X-axis ticks every 1
plt.plot(x_vals, ranks)

# Show the plot
plt.show()
